# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/content/House Price India.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# importing necessary libraries
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/House Price India.csv')
# importing the dataset and saving it in df dataframe
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.corr()
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
plt.figure(figsize=(17,12),dpi=200)
sns.heatmap(df.corr(),annot=True);

# %%
sns.scatterplot(data=df,x='Built Year',y='Renovation Year')
# Out:
# <Axes: xlabel='Built Year', ylabel='Renovation Year'>

# %%
sns.countplot(data=df,x='number of bedrooms')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='count'>

# %%
sns.scatterplot(data=df,x='number of bedrooms',y='lot area',hue='Price')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='lot area'>

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df['number of bedrooms']
# Out:
# 0        5
# 1        4
# 2        5
# 3        4
# 4        3
#         ..
# 14615    2
# 14616    3
# 14617    2
# 14618    4
# 14619    3
# Name: number of bedrooms, Length: 14620, dtype: int64

# %%
df.rename(columns={'number of bathrooms':'number_of_bathrooms'},inplace=True);

# %%
df['number_of_bathrooms']
# Out:
# 0        2.50
# 1        2.50
# 2        2.75
# 3        2.50
# 4        2.00
#          ...
# 14615    1.50
# 14616    2.00
# 14617    1.00
# 14618    1.00
# 14619    1.00
# Name: number_of_bathrooms, Length: 14620, dtype: float64

# %%
sns.countplot(data=df,x='number_of_bathrooms')
# Out:
# <Axes: xlabel='number_of_bathrooms', ylabel='count'>

# %%
df.drop(['id','Date'],axis=1,inplace=True)

# %%
df
# Out:
#        number of bedrooms  number_of_bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
X = df.drop('Price',axis=1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ 414149.74368979,  424216.24443223,  376467.39662401, ...,
#         429009.87976961, 1108319.2519311 ,   91120.26741484])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 123877.70028954529

# %%
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
rmse
# Out:
# np.float64(201875.6012154068)

# %%
from sklearn.linear_model import ElasticNet
el_model = ElasticNet()

# %%
para = {'alpha':[0.1,1,5,10,100],'l1_ratio':[.1,.5,.7,.95,.99,1]}

# %%
model.score(x_test,y_test)
# Out:
# 0.6965383124301988

# %%
el_model =ElasticNet(alpha=1,l1_ratio=0.7)

# %%
el_model.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=1, l1_ratio=0.7)

# %%
el_model.score(x_test,y_test)
# Out:
# 0.6797909422595427
